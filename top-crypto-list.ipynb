L", "UT", "OSA", "LEO", "NOS", "PXL", "NBOT", "CURE", "CCX", 42, "TOL", "XPC", "CAPP", "NKC", "HBX", "ENQ", "WEBD", "COS", "HVN", "TFB", "MAS", "BOOM", "EKO", "PRE", "OBITS", "IFC", "DAT", "BKX", "NVC", "ZUC", "AKRO", "A", "SHND", "VRC", "AXPR", "FLIXX", "SKCH", "UDOO", "DEEX", "D", "NOTE", "CSPN", "DYN", "IPL", "AMN", "XBC", "ACAT", "GMB", "FTI", "WET", "ACM", "STK", "SKB", "FREE", "AWC", "QAC", "BOMB", "DIG", "CEN", "MTC", "BTCP", "CLB", "ORMEUS", "LCS", "WNL", "CARD", "CRC", "ESBC", "SS", "RTE", "BTCZ", "NOIA", "CYBR", "KARMA", "ZER", "THRT", "LIT", "NEXT", "TRY", "NCC", "TZC", "COVA", "MVP", "BWT", "GOT", "NBX", "HOLD", "MPG", "NANJ", "MESG", "EXP", "GIO", "LQD", "EXY", "AVT", "KLN", "ECOM", "BBC", "INXT", "CVN", "AIT", "BANCA", "PIRL", "XQR", "TN", "XCM", "PKT", "DXT", "CRYP", "MEME", "MTX", "VDX", "XEL", "PDATA", "0xBTC", "RBTC", "FACE", "LOBS", "CATT", "LUNES", "UFR", "UNI", "KZE", "OWN", "MIC", "BDG", "FXT", "AYA", "OWC", "TCASH", "RATING", "MNC", "EQUAD", "COT", "PYLNT", "RYO", "EBST", "XWP", "DBET", "ZXC", "QBT", "AAC", "PLAY", "ASG", "MVC", "ESS", "SPHTX", "HKN", "BCS", "BSTY", "DATX", "ZENI", "ZSC", "PTON", "EXCL", "TGAME", "PHI", "FSBT", "ZEBI", "SMLY", "DYNMT", "MMO", "BOB", "CBIX", "FKX", "HNB", "CNUS", "BEST", "BETHER", "EVN", "ZLA", "FOTA", "MNX", "BNY", "WIKEN", "NEWS", "MBN", "PASS", "BBP", "ACE", "BITX", "OLXA", "COFI", "SINS", "XSG", "MCT", "ZAP", "ERT", "HQX", "TCC", "VNX", "XBI", "ONG", "SPD", "GRFT", "UND", "GEM", "TEAM", "MIB", "RED"]

#tradable on coinbase as of november 2021, +XRP which was delisted in Jan2021
#note: I could not get a precise list of available ones as of Jan2020
tradedOnCoinbase = ["ZRX", "INCH", "AAVE", "ALCX", "ACH", "AGLD", "ALGO", "AMP", "FORTH", "ANKR", "ARPA", "ASM", "REP", "AVAX", "AXS", "BADGER", "BAL", "BNT", "BAND", "BOND", "BAT", "BTC", "AUCTION", "BTRST", "ADA", "CTSI", "CELO", "LINK", "CHZ", "CVC", "CLV", "COMP", "ATOM", "COTI", "CRO", "CRV", "DAI", "DASH", "MANA", "DDX", "YFII", "DNT", "DOGE", "ENJ", "MLN", "EOS", "ETH", "ETC", "ENS", "FET", "FIL", "FX", "GALA", "GTC", "GNT", "GYEN", "FARM", "ZEN", "RLC", "ICP", "IOTX", "JASMY", "KEEP", "KRL", "KNC", "LCX", "LTC", "LPT", "LOOM", "LRC", "MKR", "MASK", "MIR", "MUSD", "NKN", "NU", "NMR", "OMG", "OXT", "OGN", "TRAC", "ORN", "PAX", "PERP", "PLA", "DOT", "MATIC", "POLY", "POWR", "QNT", "QUICK", "RAD", "RAI", "RLY", "RGT", "RARI", "REN", "REQ", "SHIB", "SKL", "SOL", "XLM", "STORJ", "SUKU", "SUSHI", "SNX", "BTC", "TRB", "UST", "USDT", "XTZ", "GRT", "TRIBE", "TRU", "UMA", "UNI", "USDC", "VGX", "WBTC", "WCFG", "WLUNA", "XYO", "YFI", "ZEC","XRP"]

stableCoins = ["USDT","USDC","BUSD","UST","DAI","TUSD","USDP","USDN","RSR","FEI","HUSD","FRAX","LUSD","TRIBE","GUSD","USDX","XSGD","CUSD","VAI","SUSD","EURS","SBD","QC","DGD","MUSD","USDK","RSV","OUSD","IDRT","BITCNY","DGX","EOSDT","XCHF","XAUR","USNBT","USDS","ITL","USDP","TRYB","EURT","BRCP","CEUR","PAR","MTR","ALUSD","COFFIN","XUSD","MDO","MDS","DPT","USDB","KBC","USDQ","1GOLD","BVND","ZUSD","USDFL","BITUSD","BITGOLD","BITEUR","HGT","CONST","XEUR","BGBP","EBASE","BKRW","USDL","UETH","USDEX","FLUSD","DUSD"]

#Carlo advised to add these which were coins that came out later in the year2020.
toAdd = ["SOL","AVAX","DOT"]

# %%
top = []

for crypto in top1000:
    if crypto in tradedOnCoinbase and crypto not in stableCoins:
        top.append(crypto)

top += toAdd
top
# Out:
# ['BTC',
#  'ETH',
#  'XRP',
#  'LTC',
#  'EOS',
#  'XLM',
#  'ADA',
#  'XTZ',
#  'ATOM',
#  'LINK',
#  'ETC',
#  'DASH',
#  'CRO',
#  'MKR',
#  'DOGE',
#  'BAT',
#  'ZEC',
#  'PAX',
#  'SNX',
#  'ALGO',
#  'ZRX',
#  'REP',
#  'OMG',
#  'UNI',
#  'ENJ',
#  'ZEN',
#  'QNT',
#  'MANA',
#  'MATIC',
#  'KNC',
#  'RLC',
#  'REN',
#  'CHZ',
#  'GNT',
#  'FET',
#  'LRC',
#  'IOTX',
#  'LOOM',
#  'POWR',
#  'BNT',
#  'NMR',
#  'STORJ',
#  'CVC',
#  'REQ',
#  'NKN',
#  'FX',
#  'POLY',
#  'VGX',
#  'ARPA',
#  'ANKR',
#  'PLA',
#  'WBTC',
#  'MLN',
#  'BAND',
#  'DNT',
#  'TRAC',
#  'GTC',
#  'TRB',
#  'MIR',
#  'XYO',
#  'COTI',
#  'KRL',
#  'PLA',
#  'UNI',
#  'SOL',
#  'AVAX',
#  'DOT']

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=922ad83b-862b-48ba-b595-658274e50834' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
