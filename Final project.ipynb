# %%
print("This is a test for github integration changed")
# Out:
# This is a test for github integration changed

# %%
#import networkx as nx 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as sp

import os

# %%
path = "data/USD/"

# %%
#do not run, memory runs out

data = []

errors = ["USD-QNT_price_hist_2020-01-01_2021-11-25.csv"]

for filename in os.listdir('data/USD'):
    print(filename)
    if filename not in errors:
        data.append(pd.read_csv(path + filename))

df = pd.concat(data, axis=0, ignore_index=True)
# Out:
# USD-XYO_price_hist_2020-01-01_2021-11-25.csv
# USD-MATIC_price_hist_2020-01-01_2021-11-25.csv
# USD-QNT_price_hist_2020-01-01_2021-11-25.csv
# USD-LRC_price_hist_2020-01-01_2021-11-25.csv
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3173: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_ETH = pd.read_csv(path + "USD-ETH_price_hist_2020-01-01_2021-11-25.csv")
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3173: DtypeWarning: Columns (5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_ETH
# Out:
#                time exchange fsym tsym    close     high      low     open  \
# 0        1577836800   CCCAGG  ETH  USD   128.83   128.92   128.83   128.91
# 1        1577836860   CCCAGG  ETH  USD   128.83   128.83   128.83   128.83
# 2        1577836920   CCCAGG  ETH  USD   128.78   128.83   128.78   128.83
# 3        1577836980   CCCAGG  ETH  USD   128.80   128.81   128.77   128.78
# 4        1577837040   CCCAGG  ETH  USD   128.68    128.8   128.68    128.8
# ...             ...      ...  ...  ...      ...      ...      ...      ...
# 1000795  1637884500   CCCAGG  ETH  USD  4520.20  4523.56   4519.8  4523.07
# 1000796  1637884560   CCCAGG  ETH  USD  4519.87  4521.55  4519.86   4520.2
# 1000797  1637884620   CCCAGG  ETH  USD  4520.55   4520.8  4517.97  4519.87
# 1000798  1637884680   CCCAGG  ETH  USD  4519.26  4520.92  4518.87  4520.55
# 1000799  1637884740   CCCAGG  ETH  USD  4523.80  4523.89  4517.16  4519.26
#
#          volumefrom   volumeto
# 0             68.61    8896.65
# ...

# %%
_deepnote_run_altair(df_ETH, """{"$schema":"https://vega.github.io/schema/vega-lite/v4.json","mark":{"type":"line","tooltip":{"content":"data"}},"height":220,"autosize":{"type":"fit"},"data":{"name":"placeholder"},"encoding":{"x":{"field":"time","type":"quantitative","sort":null,"scale":{"type":"linear","zero":false}},"y":{"field":"close","type":"quantitative","sort":null,"scale":{"type":"linear","zero":false}},"color":{"field":"","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}}}}""")
# Out:
# alt.Chart(...)

# %%
df_BTC = pd.read_csv(path + "USD-BTC_price_hist_2020-01-01_2021-11-25.csv")
df_LTC = pd.read_csv(path + "USD-LTC_price_hist_2020-01-01_2021-11-25.csv")
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3173: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
li = []
li.append(df_BTC)
li.append(df_ETH)
li.append(df_LTC)
df = pd.concat(li, axis=0, ignore_index=True)

# %%
df
# Out:
#                time exchange fsym tsym    close     high      low     open  \
# 0        1577836800   CCCAGG  BTC  USD  7197.87  7198.83   7177.4  7183.88
# 1        1577836860   CCCAGG  BTC  USD  7196.69  7198.64  7195.68  7197.87
# 2        1577836920   CCCAGG  BTC  USD  7195.84   7197.1  7195.78  7196.69
# 3        1577836980   CCCAGG  BTC  USD  7197.82  7197.82  7195.68  7195.84
# 4        1577837040   CCCAGG  BTC  USD  7195.11  7197.99  7195.11  7197.82
# ...             ...      ...  ...  ...      ...      ...      ...      ...
# 3002395  1637884500   CCCAGG  LTC  USD   223.09   223.15   223.05   223.13
# 3002396  1637884560   CCCAGG  LTC  USD   223.10   223.16   223.05   223.09
# 3002397  1637884620   CCCAGG  LTC  USD   223.00    223.1   222.93    223.1
# 3002398  1637884680   CCCAGG  LTC  USD   222.98   223.04   222.87    223.0
# 3002399  1637884740   CCCAGG  LTC  USD   223.04   223.04   222.82   222.98
#
#          volumefrom   volumeto
# 0            22.370  162091.05
# ...

# %%
_deepnote_run_altair(df, """{"$schema":"https://vega.github.io/schema/vega-lite/v4.json","mark":{"type":"line","tooltip":{"content":"data"}},"height":220,"autosize":{"type":"fit"},"data":{"name":"placeholder"},"encoding":{"x":{"field":"time","type":"quantitative","sort":null,"scale":{"type":"linear","zero":false}},"y":{"field":"close","type":"quantitative","sort":null,"scale":{"type":"linear","zero":false}},"color":{"field":"fsym","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}}}}""")
# Out:
# alt.Chart(...)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=922ad83b-862b-48ba-b595-658274e50834' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
